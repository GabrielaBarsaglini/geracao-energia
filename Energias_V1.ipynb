# %%
import pandas as pd

import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r'D:\Users\Usuario\Desktop\Projeto Energia\empreendimento-operacao-historico.csv', sep=';')

# %%
df.head()
# Out:
#   DatGeracaoConjuntoDados SigTipoGeracao  QtdUsinasPeriodo  \
# 0              2025-02-21            CGH                 0
# 1              2025-02-21            EOL                 7
# 2              2025-02-21            PCH               303
# 3              2025-02-21            UFV                 0
# 4              2025-02-21            UHE               133
#
#   MdaPotenciaInstaladaKW  MesReferencia  AnoReferencia
# 0                    ,00             12           2001
# 1               21000,00             12           2001
# 2              855000,00             12           2001
# 3                    ,00             12           2001
# 4            61554000,00             12           2001

# %%
print(df.columns)
# Out:
# Index(['DatGeracaoConjuntoDados', 'SigTipoGeracao', 'QtdUsinasPeriodo',
#        'MdaPotenciaInstaladaKW', 'MesReferencia', 'AnoReferencia'],
#       dtype='object')

# %%
df = df.drop('DatGeracaoConjuntoDados', axis=1)

# %%
df.head()
# Out:
#   SigTipoGeracao  QtdUsinasPeriodo MdaPotenciaInstaladaKW  MesReferencia  \
# 0            CGH                 0                    ,00             12
# 1            EOL                 7               21000,00             12
# 2            PCH               303              855000,00             12
# 3            UFV                 0                    ,00             12
# 4            UHE               133            61554000,00             12
#
#    AnoReferencia
# 0           2001
# 1           2001
# 2           2001
# 3           2001
# 4           2001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SigTipoGeracao          467 non-null    object
#  1   QtdUsinasPeriodo        467 non-null    int64
#  2   MdaPotenciaInstaladaKW  467 non-null    object
#  3   MesReferencia           467 non-null    int64
#  4   AnoReferencia           467 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 18.4+ KB

# %%
encoder = LabelEncoder()
df['SigTipoGeracao_encoded'] = encoder.fit_transform(df['SigTipoGeracao']) + 1
df
# Out:
#     SigTipoGeracao  QtdUsinasPeriodo MdaPotenciaInstaladaKW  MesReferencia  \
# 0              CGH                 0                    ,00             12
# 1              EOL                 7               21000,00             12
# 2              PCH               303              855000,00             12
# 3              UFV                 0                    ,00             12
# 4              UHE               133            61554000,00             12
# ..             ...               ...                    ...            ...
# 462            UFV             18346            15088754,72              8
# 463            PCH               428             5829956,57              8
# 464            UHE               214           103196493,00              8
# 465            UTE              3024            46109738,16              8
# 466            UTN                 2             1990000,00              8
#
#      AnoReferencia  SigTipoGeracao_encoded
# ...

# %%
df = df.drop('SigTipoGeracao', axis=1)

# %%
df.head()
# Out:
#    QtdUsinasPeriodo MdaPotenciaInstaladaKW  MesReferencia  AnoReferencia  \
# 0                 0                    ,00             12           2001
# 1                 7               21000,00             12           2001
# 2               303              855000,00             12           2001
# 3                 0                    ,00             12           2001
# 4               133            61554000,00             12           2001
#
#    SigTipoGeracao_encoded
# 0                       1
# 1                       3
# 2                       4
# 3                       5
# 4                       6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   QtdUsinasPeriodo        467 non-null    int64
#  1   MdaPotenciaInstaladaKW  467 non-null    object
#  2   MesReferencia           467 non-null    int64
#  3   AnoReferencia           467 non-null    int64
#  4   SigTipoGeracao_encoded  467 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 18.4+ KB

# %%
df['MdaPotenciaInstaladaKW '] = df['MdaPotenciaInstaladaKW'].str.replace(',', '.').astype(float)
df
# Out:
#      QtdUsinasPeriodo MdaPotenciaInstaladaKW  MesReferencia  AnoReferencia  \
# 0                   0                    ,00             12           2001
# 1                   7               21000,00             12           2001
# 2                 303              855000,00             12           2001
# 3                   0                    ,00             12           2001
# 4                 133            61554000,00             12           2001
# ..                ...                    ...            ...            ...
# 462             18346            15088754,72              8           2024
# 463               428             5829956,57              8           2024
# 464               214           103196493,00              8           2024
# 465              3024            46109738,16              8           2024
# 466                 2             1990000,00              8           2024
#
#      SigTipoGeracao_encoded  MdaPotenciaInstaladaKW
# ...

# %%
df = df.drop('MdaPotenciaInstaladaKW', axis=1)

# %%
df.head()
# Out:
#    QtdUsinasPeriodo  MesReferencia  AnoReferencia  SigTipoGeracao_encoded  \
# 0                 0             12           2001                       1
# 1                 7             12           2001                       3
# 2               303             12           2001                       4
# 3                 0             12           2001                       5
# 4               133             12           2001                       6
#
#    MdaPotenciaInstaladaKW
# 0                      0.0
# 1                  21000.0
# 2                 855000.0
# 3                      0.0
# 4               61554000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   QtdUsinasPeriodo         467 non-null    int64
#  1   MesReferencia            467 non-null    int64
#  2   AnoReferencia            467 non-null    int64
#  3   SigTipoGeracao_encoded   467 non-null    int64
#  4   MdaPotenciaInstaladaKW   467 non-null    float64
# dtypes: float64(1), int64(4)
# memory usage: 18.4 KB

# %%
hm = sns.heatmap(df.corr(), annot = True)
hm.set(title = "Correlation Matrix \n")
# Out:
# [Text(0.5, 1.0, 'Correlation Matrix \n')]
